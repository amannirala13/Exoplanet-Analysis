# %%
from lightkurve import search_targetpixelfile, TessTargetPixelFile
import lightkurve as lk
import numpy as np

# %%
search_result = lk.search_targetpixelfile('TIC 280310048')
search_result
# Out:
# SearchResult containing 4 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 07 2019      SPOC     120   280310048      0.0
#   1 TESS Sector 07 2019 TESS-SPOC    1800   280310048      0.0
#   2 TESS Sector 34 2021      SPOC     120   280310048      0.0
#   3 TESS Sector 34 2021 TESS-SPOC     600   280310048      0.0

# %%
tpf = search_result[0].download(quality_bitmask="hardest")
# Out:
# WARNING: File may have been truncated: actual file length (2319253504) is smaller than the expected size (3239720640) [astropy.io.fits.file]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2836/1495250938.py in <module>
# ----> 1 tpf = search_result[0].download(quality_bitmask="hardest")
#
# ~\anaconda3\lib\site-packages\lightkurve\utils.py in wrapper(*args, **kwargs)
#     553             sys.stdout = devnull
#     554             try:
# --> 555                 return f(*args, **kwargs)
#     556             # restore to default
#     557             finally:
#
# ~\anaconda3\lib\site-packages\lightkurve\search.py in download(self, quality_bitmask, download_dir, cutout_size, **kwargs)
#     353             )
#     354
# --> 355         return self._download_one(
#     356             table=self.table[:1],
#     357             quality_bitmask=quality_bitmask,
#
# ~\anaconda3\lib\site-packages\lightkurve\search.py in _download_one(self, table, quality_bitmask, download_dir, cutout_size, **kwargs)
#     288                 )["Local Path"][0]
#     289                 log.debug("Finished downloading.")
# --> 290             return read(path, quality_bitmask=quality_bitmask, **kwargs)
#     291
#     292     @suppress_stdout
#
# ~\anaconda3\lib\site-packages\lightkurve\io\read.py in read(path_or_url, **kwargs)
#     110     if filetype is not None:
#     111         try:
# --> 112             return getattr(__import__("lightkurve"), filetype)(path_or_url, **kwargs)
#     113         except AttributeError as exc:
#     114             raise LightkurveError(
#
# ~\anaconda3\lib\site-packages\lightkurve\targetpixelfile.py in __init__(self, path, quality_bitmask, **kwargs)
#    2726         )
#    2727         self.quality_mask = TessQualityFlags.create_quality_mask(
# -> 2728             quality_array=self.hdu[1].data["QUALITY"], bitmask=quality_bitmask
#    2729         )
#    2730         # Early TESS releases had cadences with time=NaN (i.e. missing data)
#
# ~\anaconda3\lib\site-packages\astropy\utils\decorators.py in __get__(self, obj, owner)
#     775                     val = obj_dict.get(self._key, _NotFound)
#     776                     if val is _NotFound:
# --> 777                         val = self.fget(obj)
#     778                         obj_dict[self._key] = val
#     779             return val
#
# ~\anaconda3\lib\site-packages\astropy\io\fits\hdu\table.py in data(self)
#     400     @lazyproperty
#     401     def data(self):
# --> 402         data = self._get_tbdata()
#     403         data._coldefs = self.columns
#     404         data._character_as_bytes = self._character_as_bytes
#
# ~\anaconda3\lib\site-packages\astropy\io\fits\hdu\table.py in _get_tbdata(self)
#     170                                           type=np.rec.recarray)
#     171         else:
# --> 172             raw_data = self._get_raw_data(self._nrows, columns.dtype,
#     173                                           self._data_offset)
#     174             if raw_data is None:
#
# ~\anaconda3\lib\site-packages\astropy\io\fits\hdu\base.py in _get_raw_data(self, shape, code, offset)
#     529                               offset=offset)
#     530         elif self._file:
# --> 531             return self._file.readarray(offset=offset, dtype=code, shape=shape)
#     532         else:
#     533             return None
#
# ~\anaconda3\lib\site-packages\astropy\io\fits\file.py in readarray(self, size, offset, dtype, shape)
#     327                             raise
#     328
# --> 329                 return np.ndarray(shape=shape, dtype=dtype, offset=offset,
#     330                                   buffer=self._mmap)
#     331             else:
#
# TypeError: buffer is too small for requested array

# %%
tpf.plot(aperture_mask=tpf.pipeline_mask)
# Out:
# <AxesSubplot:title={'center':'Target ID: 445258206, Cadence: 386805'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
tpf.interact()
# Out:
# <script id="2568">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:51417/autoload.js?bokeh-autoload-element=2568&bokeh-absolute-url=http://localhost:51417&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
tpf.interact_sky()
# Out:
# <script id="3807">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:55818/autoload.js?bokeh-autoload-element=3807&bokeh-absolute-url=http://localhost:55818&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
# WARNING: UnitsWarning: Unit 'e' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING:astroquery:UnitsWarning: Unit 'e' not supported by the VOUnit standard.

# %%
aperture_mask = tpf.create_threshold_mask(threshold=10)
lc = tpf.to_lightcurve()
lc.scatter()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
lc.interact_bls()
# Out:
# <script id="4995">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:57974/autoload.js?bokeh-autoload-element=4995&bokeh-absolute-url=http://localhost:57974&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
flat_lc = lc.remove_nans().flatten()
flat_lc.scatter()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
periodogram = flat_lc.to_periodogram(method="bls")
periodogram.plot()
period = periodogram.period_at_max_power
print("Period [days]:",period)
# Out:
# Period [days]: 6.506509965678711 d

# %%
# phase folding the signal frequency
folded_lc = flat_lc.fold(period=period)
folded_lc.scatter(s=0.1)
# Out:
# <AxesSubplot:xlabel='Phase [JD]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
# Out:
# <script id="3923">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:55829/autoload.js?bokeh-autoload-element=3923&bokeh-absolute-url=http://localhost:55829&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=3923&bokeh-absolute-url=http://localhost:55829&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:55829', method='GET', uri='/autoload.js?bokeh-autoload-element=3923&bokeh-absolute-url=http://localhost:55829&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "C:\Users\hp\anaconda3\lib\site-packages\tornado\web.py", line 1704, in _execute
#     result = await result
#   File "C:\Users\hp\anaconda3\lib\site-packages\bokeh\server\views\autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "C:\Users\hp\anaconda3\lib\site-packages\bokeh\server\views\session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "C:\Users\hp\anaconda3\lib\site-packages\bokeh\server\contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "C:\Users\hp\anaconda3\lib\site-packages\bokeh\application\application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "C:\Users\hp\anaconda3\lib\site-packages\bokeh\application\handlers\function.py", line 143, in modify_document
#     self._func(doc)
#   File "C:\Users\hp\anaconda3\lib\site-packages\lightkurve\interact_bls.py", line 719, in _create_interact_ui
#     transit_time_format=result["transit_time"].format,
#   File "C:\Users\hp\anaconda3\lib\site-packages\astropy\units\quantity.py", line 1016, in __getattr__
#     raise AttributeError(
# AttributeError: 'Quantity' object has no 'format' member
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=3923&bokeh-absolute-url=http://localhost:55829&resources=none (::1) 485.40ms

# %%
bin_folded_lc = folded_lc.bin(binsize=40)
bin_folded_lc.plot()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_12920/3852341979.py:1: LightkurveDeprecationWarning: "binsize" was deprecated in version 2.0 and will be removed in a future version.
#         Use time_bin_size instead.
#   bin_folded_lc = folded_lc.bin(binsize=40)
# <AxesSubplot:xlabel='Phase [JD]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>
